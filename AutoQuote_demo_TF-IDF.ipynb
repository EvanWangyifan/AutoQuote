# %%
import pytesseract
from PIL import Image
import pdf2image
from huggingface_hub import InferenceClient
import json
import re
import pandas as pd
import fasttext.util
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer

# %%
API_TOKEN = "hf_xxxxx" # replace with your API token

client = InferenceClient(
    model="meta-llama/Meta-Llama-3.1-8B-Instruct",
    token=API_TOKEN,
)

# %%
def OCR_extraction(pages):
    # Extract text from image
    text = []
    for page in pages:
        text.append(pytesseract.image_to_string(page))
    return text

def extract_line_items_llama(text):
    prompt_template = """Here's my OCR output from a pdf doc for the purpose of industrial quote generation. 
                        Generate a json file containing list of industrial product_name alphabetical only without special characters 
                        (eg. "Corner Bead paper faced 10"; "5 8 Firecode Core"; "Easy Clip S545") 
                        based on the parsed output (use common sense and imagining the parsed format from a table where related information may be parsed in separate lines), 
                        ignore the quantity (eg. 35,288.66) and unit (eg. 1,000 LF or 1,000 SF or 37.00 EA) in the parsed text:
                        
                        Only output something like this structured output without explanation and code:
                        [
                            {{ "product": "Product A"}},
                            {{ "product": "Product B"}},
                            {{ "product": "Product C"}}, 
                            ...
                        ]:
                        
                        {text}
                        """
    prompt = prompt_template.format(text=text)
    messages = [{"role": "system", "content": "You are a bot that responds only with the extracted product list."},
                {"role": "user", "content": prompt}]
    print("Waiting for Meta-Llama-3.1-8B-Instruct to generate output...")
    response = client.chat_completion(
        messages=messages,
        max_tokens=1650,
        stream=True,
        # temperature=0.0,
    )

    structured_line_items = ""
    for message in response:
        structured_line_items += message.choices[0].delta.content
    
    return structured_line_items.strip()


def extract_product_names(structured_line_items_str):
    try:
        # Use a regular expression to extract the product names
        product_names = re.findall(r'"product":\s*"(?:[^"\\]|\\.)*"', structured_line_items_str)
        # Remove the "product": and quotes from the matches
        product_names = [match[12:-1] for match in product_names]
        return product_names
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return None

# %%
# Convert PDF to images
request_1 = pdf2image.convert_from_path('/Users/evanwyf/Downloads/AutoQuote/Data/Request-Response 1/Request 1.pdf')
request_2 = pdf2image.convert_from_path('/Users/evanwyf/Downloads/AutoQuote/Data/Request-Response 2/Request 2.pdf')
product_db = pd.read_csv('/Users/evanwyf/Downloads/AutoQuote/Data/ProductDB.csv')

# Extract text from each image
text = OCR_extraction(request_2)
# Combine the extracted text into a single string
combined_text = " ".join(text)

# Extract the line items from the combined text
structured_line_items_str = extract_line_items_llama(combined_text)
if structured_line_items_str:
    print("Extracted Items:", structured_line_items_str)
    product_names = extract_product_names(structured_line_items_str)
    print("# of extracted products:", len(product_names))

    # Load the product database
    product_names_db = product_db.iloc[:, 2].tolist()  # Assuming the product name is in the third column
    print("# of DB products:", len(product_names_db))

    # Initialize BERT tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Waiting for Meta-Llama-3.1-8B-Instruct to generate output...
# Extracted Items: [
#     {"product": "2 x 4 Fire Treated"},
#     {"product": "2 x 4 Pressure Treated Roof Blocking"},
#     {"product": "2 x 4 Pressure Treated Window Blkg"},
#     {"product": "2 x 6 Fire Treated"},
#     {"product": "2 x 6 Pressure Treated Roof Blocking"},
#     {"product": "2 x 6 Pressure Treated Window Bikg"},
#     {"product": "2 x 8 Fire Treated"},
#     {"product": "2 x 8 Pressure Treated Roof Blocking"},
#     {"product": "2 x 8 Pressure Treated, Window Blkg"},
#     {"product": "4 x 4 fire treated plywood (PLY 58FT)"},
#     {"product": "4  x 8' (PLY12FT)"},
#     {"product": "4' x 8' (PLY34FT)"},
#     {"product": "4' x 8' CDX F/R Plywood"},
#     {"product": "4' x 8' Plywood 11/8\" (PLY136FT)"},
#     {"product": "4' x 8' T&G Underlayment (PLY 34UNDTG)"},
#     {"product": "5  8\" Cement Backer Board ( 4' x 4' ) (CBB58)"},
#     {"product": "5 8 fire treated plywood, 4’ x 8' (PLY58FT)"},
#     {"product": "5/8  - Cement Board Sheathing, Exterior, 4‘ x 8'  "},
#     {"product": "5/8' - Dens-Shield Tile Backer Board (  4' x 8' ) (GPDGTBB58)"},
#     {"product": "5/8' Cement Board Sheathing, Exterior, 4‘ x 8' (CBSHEATHS58)"},
#     {"product": "5/8' Dens-Glass Gold Sheathing, 4' x 8'  "(GPDGG58)"},
#     {"product": "5/8\" Backer Board (X58)"},
#     {"product": "5/8\" Densboard Sheathing, 4' x 8' ( ")
#     {"product": "5/8\" Densboard Sheathing, 4' x 8’ (GPDG58)"},
#     {"product": "3/4  11/8\" (PWD136FT)"},
#     {"product": "3/4  - Dens-Shield 11/8\"  "},
#     {"product": "3/4\" - 11/8\" Plywood ( 4' x 4' ) (PWD136FT)"},
#     {"product": "3/4\" CDX Fire-treated Plywood, 4' x 8' (PLY34FT)"},
#     {"product": "3/4\" CDX F/R Plywood, 4' x 8 (PLY12FT)"},
#     {"product": "3/4\" Plywood (PLY12FT)"},
#     {"product": "3/4\" T&G Underlayment, 4 x 8' (PLY34UNDTG)"},
#     {"product": "8" x 20ga Ext Track, 10° (T800T125-54)"},
#     {"product": "10” x 2”  x 16ga Ext Stud, 18' (S1000S200-54)"},
#     {"product": "11/21/2019 = 10"},
#     {"product": "110.00 LF"},
#     {"product": "111/21/2019 "},
#     {"product": "12ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "12ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "12” x 20ga  Flat Stock, 10 (FS120)"},
#     {"product": "12’ (CM640)"},
#     {"product": "13,031.22 EA."},
#     {"product": "13/21/ 12: 9 rend areas: joists ]"},
#     {"product": “13/BCFLOXCIRC610 ”},
#     {"product": "14ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC UC UC devices  "},
#     {"product": "14ga UC devices  "},
#     {"product": "14ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "14” x 20ga  Flat Stock, 10 (FS140)"},
#     {"product": "150plalam (TNH  "},
#     {"product": "190esselml onout 165 woow outerof car liquid  "},
#     {"product": "190essel ]"},
#     {"product": “19/BCFLOXCIRC610 ”},
#     {"product": "2 x 4 Fire Treated"},
#     {"product": “23 mil14 pull'}100½alnovenade ")
#     {"product": "2-1/2" easure dB ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "2-1/2  21 ii r'^ equip (ION SEEK OST temp gi PCa Gas  "},
#     {"product": "2-1/2' x 20ga Int Stud (sizes 2) (S  "},
#     {"product": "2  ]"},
#     {"product": “2/BCFLOXCIRC610 ”},
#     {"product": "2’ x 4' (CBB58)"},
#     {"product": "2’ x 6  "},
#     {"product": "2x ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "2x6  "},
#     {"product": "2x ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "4 strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "3-1 weil veil dub dich ti ii r'^ equip (ION SEEK OST temp gi PCa Gas  "},
#     {"product": "3-5/8' x 20ga Int Stud (sizes 7) (S  "},
#     {"product": "3  ]"},
#     {"product": “3/BCFLOXCIRC610 ”},
#     {"product": "3’ (PLY  "},
#     {"product": "3” 11/8\" (PWD136FT)"},
#     {"product": "3isserail temp gi PCa Gas  "},
#     {"product": "374 rail temp gi PCa Gas  "},
#     {"product": "40of car liquid  "},
#     {"product": "400  ]"},
#     {"product": “4/BCFLOXCIRC610 ”},
#     {"product": "4’ GPDGTBB58)"},
#     {"product": “44 mil14 pull'}100½alnovenade "}
#     {"product": "4“  "},
#     {"product": "5 dB ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "5-1/ easure dB ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  "},
#     {"product": "5” 8\" Backer Board (X58)"},
#     {"product": "5“  Gas  "},
#     {"product": "50 rail temp gi PCa Gas  "},
#     {"product": "508of car liquid  "},
#     {"product": "512 mil14 pull'}100½ ail utc G C Cap strip Carrier/an aus
# # of extracted products: 77
# # of DB products: 9813
# /Users/evanwyf/miniconda3/envs/auto_quote/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def custom_tokenize(text, tokenizer):
    # Use BERT tokenizer to tokenize text
    tokens = tokenizer.tokenize(text)
    return tokens

def compute_similarity_scores_tfidf(extracted_names, product_names, tokenizer):
    # Combine all names into a single list
    all_names = extracted_names + product_names

    # Create a TF-IDF vectorizer with custom tokenization using BERT tokenizer
    vectorizer = TfidfVectorizer(tokenizer=lambda text: custom_tokenize(text, tokenizer), stop_words='english', ngram_range=(1, 3))

    # Fit and transform the vectorizer on all names
    tfidf_matrix = vectorizer.fit_transform(all_names)

    # Split the TF-IDF matrix back into extracted names and product names
    extracted_tfidf = tfidf_matrix[:len(extracted_names)]
    product_tfidf = tfidf_matrix[len(extracted_names):]

    # Compute cosine similarity scores
    similarity_scores = cosine_similarity(extracted_tfidf, product_tfidf)

    return similarity_scores

def get_top_n_recommendations_tfidf(similarity_scores, product_names, n=10):
    recommendations = []
    for scores in similarity_scores:
        # Get the indices of the top-n scores
        top_indices = scores.argsort()[-n:][::-1]
        top_recommendations = [product_names[i] for i in top_indices]
        recommendations.append(top_recommendations)
    return recommendations

# %%
# Compute similarity scores using TF-IDF
similarity_scores = compute_similarity_scores_tfidf(product_names, product_names_db, tokenizer)

# Get top-10 recommendations for each extracted product name
top_10_recommendations = get_top_n_recommendations_tfidf(similarity_scores, product_names_db)
for i, recommendations in enumerate(top_10_recommendations):
    print(f"Top-10 Recommendations for Request No.{i+1} '{product_names[i]}': {recommendations}")
# Out:
# /Users/evanwyf/miniconda3/envs/auto_quote/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /Users/evanwyf/miniconda3/envs/auto_quote/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:406: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['##af', '##by', '##ce', '##e', '##g', '##gs', '##her', '##hit', '##how', '##in', '##ly', '##on', '##oun', '##t', '##ter', '##up', 'couldn', 'e', 'hasn', 'noon', 'w'] not in stop_words.
#   warnings.warn(
# Top-10 Recommendations for Request No.1 '2 x 4 Fire Treated': ['ANGL 2 X 4-16', 'ANGL 2 X 4-14', 'ANGL 2 X 4 16GA', 'CORNERITE - 2 IN X 2 IN X 4FT', 'ANGL 2 X 4 (18G)', 'ANGL 2 X 4.5-20', 'ANGL 2 X 4 (12GA)', 'DZF 2 X 4 X 2-16GA', 'DZF 2 X 4 X 2-20GA', 'ANGL 2 X 4 (25GA)']
# Top-10 Recommendations for Request No.2 '2 x 4 Pressure Treated Roof Blocking': ['ANGL 2 X 4-16', 'ANGL 2 X 4-14', 'ANGL 2 X 4 16GA', 'CORNERITE - 2 IN X 2 IN X 4FT', 'ANGL 2 X 4 (18G)', 'ANGL 2 X 4.5-20', 'ANGL 2 X 4 (12GA)', 'DZF 2 X 4 X 2-16GA', 'DZF 2 X 4 X 2-20GA', 'ANGL 2 X 4 (25GA)']
# Top-10 Recommendations for Request No.3 '2 x 4 Pressure Treated Window Blkg': ['ANGL 2 X 4-16', 'ANGL 2 X 4-14', 'ANGL 2 X 4 16GA', 'DCV58-200S BLK - 10FT', 'ANGL 2 X 4 (18G)', 'CORNERITE - 2 IN X 2 IN X 4FT', 'ANGL 2 X 4.5-20', 'ANGL 2 X 4 (12GA)', 'DZF 2 X 4 X 2-16GA', 'DZF 2 X 4 X 2-20GA']
# Top-10 Recommendations for Request No.4 '2 x 6 Fire Treated': ['ANGL 2 X 6-16', 'ANGL 2 X 6-14', 'ANGL 2 X 6-12', 'CDMB 2 X 6', 'CDBV 2 X 6', 'ANGL 2 X 6-33(20GA)', 'ANGL 2 X 6-30(20GA)', 'ANGL 2 X 6-43(18GA)', '600BHC6-68 - 6 X 1-1/2 X 6 - 14G', '600BHC6-54 - 6 X 1-1/2 X 6 - 16G']
# Top-10 Recommendations for Request No.5 '2 x 6 Pressure Treated Roof Blocking': ['ANGL 2 X 6-16', 'ANGL 2 X 6-14', 'ANGL 2 X 6-12', 'CDMB 2 X 6', 'CDBV 2 X 6', 'ANGL 2 X 6-33(20GA)', 'ANGL 2 X 6-30(20GA)', 'ANGL 2 X 6-43(18GA)', '600BHC6-68 - 6 X 1-1/2 X 6 - 14G', '600BHC6-54 - 6 X 1-1/2 X 6 - 16G']
# Top-10 Recommendations for Request No.6 '2 x 6 Pressure Treated Window Bikg': ['ANGL 2 X 6-16', 'ANGL 2 X 6-14', 'ANGL 2 X 6-12', 'CDMB 2 X 6', 'CDBV 2 X 6', 'ANGL 2 X 6-33(20GA)', 'ANGL 2 X 6-30(20GA)', 'ANGL 2 X 6-43(18GA)', '600BHC6-68 - 6 X 1-1/2 X 6 - 14G', '600BHC6-54 - 6 X 1-1/2 X 6 - 16G']
# Top-10 Recommendations for Request No.7 '2 x 8 Fire Treated': ['CDMB 2 X 8', 'CORNERITE - 2 IN X 2 IN X 8FT', 'CDBV 2 X 8', '2-1/2 X 8 STEEL STUD 20 GA', '2-1/2 X 8 STEEL STUD 25 GA', '#66 SF CASING 1/2 IN X 8FT', 'ANGL 2 X 8-54(16GA)', 'ANGL 2 X 8-33(20GA)', 'ANGL 2 X 8-68(14GA)', '1/2 IN X 8FT VINYL J-TRIM']
# Top-10 Recommendations for Request No.34 '11/21/2019 = 10': ['STRUCTURAL TRACK 3-11/16IN 18G 1.5IN LEG', 'STRUCTURAL TRACK 3-11/16IN 16G 1.5IN LEG', 'HEMMED H-STUD 11/16 LEG', 'UNHEMMED H-STUD 11/16 LEG', 'STRUCTURAL STUD 11-1/2IN 16G 1-5/8IN FL', 'STRUCTURAL STUD 11-1/2IN 18G 1-5/8IN FL', 'STRUCTURAL STUD 11-1/2IN 14G 1-5/8IN FL', 'STRUCTURAL STUD 11-1/2IN 12G 1-5/8IN FL', 'STR TRACK 11-1/2IN 16G 1-1/4IN LEGS', 'STR TRACK 11-1/2IN 18G 1-1/4IN LEGS']
# Top-10 Recommendations for Request No.35 '110.00 LF': ['COIL 3.00IN - 20G (33MIL)', 'LHJT (L)', 'ANGL 2 X 2-16GA (110 DEG)', 'ANGL 4 X 4 (16GA) @ 110 DEG', 'ANGL 2 X 2 (20G) @110DEG', 'LSS4.12', 'LSS2.1', 'LSS5.12', 'LSS2.06', 'FASTTOP CLIP 800 - 25 PCS/CTN (INC. 110']
# Top-10 Recommendations for Request No.36 '111/21/2019 ': ['3/8 IN J-TRIM W/W 3-1/2 IN FLG', '7/8 IN J-TRIM W/W 3-1/2 IN FLG', '3/8 IN J-TRIM N/W 3-1/2 IN FLG', '7/8 IN J-TRIM N/W 3-1/2 IN FLG', '1/2 IN J-TRIM W/W 3-1/2 IN FLG', '3/4 IN J-TRIM W/W 3-1/2 IN FLG', '1/2 IN J-TRIM N/W 3-1/2 IN FLG', '3/4 IN J-TRIM N/W 3-1/2 FLG', 'STRUCTURAL STUD 3-5/8IN 20G 2-1/2IN FL', 'STRUCTURAL STUD 3-5/8IN 16G 2-1/2IN FL']
# Top-10 Recommendations for Request No.37 '12ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'STRAP 12-12GA', 'ANGL 2 X 4 (12GA)', 'STRAP 2-12GA', 'STRAP 1-12GA', '12 IN MAXTRAK 12GA', 'STRAP 5-12GA', 'STRAP 3-12GA']
# Top-10 Recommendations for Request No.38 '12ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'STRAP 12-12GA', 'ANGL 2 X 4 (12GA)', 'STRAP 2-12GA', 'STRAP 1-12GA', '12 IN MAXTRAK 12GA', 'STRAP 5-12GA', 'STRAP 3-12GA']
# Top-10 Recommendations for Request No.39 '12” x 20ga  Flat Stock, 10 (FS120)': ['FS300 - 10 FT', 'CDLMS12', 'LS12G', 'FS100 - 10 FT', 'FS600 - 10 FT', 'FS200 - 10 FT', 'FS400 - 10 FT', 'ANGL 4 X 10 (20G)', 'CDST LS12', 'CDLMS12G']
# Top-10 Recommendations for Request No.40 '12’ (CM640)': ['BC64', 'BCQ64', 'IS300-12', 'ANGL 4 X 12 (12G)', 'ANGL 3 X 12 (12G)', 'ANGL 1.5 X 12 (12G)', 'SHEET 4FT X 12FT (12G)', 'STRAP 3.5 (12G)', 'ANGL 2 X 4 (12GA)', 'STRAP 10.5 (12G)']
# Top-10 Recommendations for Request No.41 '13,031.22 EA.': ['EA66', 'EA44', 'ATHI1.81/22', 'ATHI1.68/22', 'CDSTHI1.81/22', 'DZF 1.5X1.5X1.5-16', 'ISU1.81/9.5', 'STHI1.81/22G', 'DZF 1.5X1.5X1.5-18GA', 'RSV1.56/9.5']
# Top-10 Recommendations for Request No.42 '13/21/ 12: 9 rend areas: joists ]': ['H5.25/12', 'H3.25/12', 'HTF5.25/12', 'HTF3.25/12', 'RCS3/40/12', 'HHDTP5.25/12', 'HHDTP3.25/12', 'HHDTP7.25/12', 'HHDTP5.50/12', 'HHDTP2.75/12']
# Top-10 Recommendations for Request No.43 '14ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC UC UC devices  ': ['UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'TILE CAP', 'STRAP 14-14GA', 'STRAP 2-14GA', 'STRAP 3-14GA', 'STRAP 5-14GA', 'STRAP 1-14GA', 'LHJT (L)', 'STRAP 18 IN (14GA)']
# Top-10 Recommendations for Request No.44 '14ga UC devices  ': ['STRAP 14-14GA', 'STRAP 2-14GA', 'STRAP 3-14GA', 'STRAP 5-14GA', 'STRAP 1-14GA', 'STRAP 4-14GA', 'STRAP 8-14GA', 'STRAP 6-14GA', 'STRAP 10-14GA', 'STRAP 9-14GA']
# Top-10 Recommendations for Request No.45 '14ga ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'STRAP 14-14GA', 'STRAP 2-14GA', 'STRAP 3-14GA', 'STRAP 5-14GA', 'STRAP 1-14GA', 'LHJT (L)', 'STRAP 18 IN (14GA)']
# Top-10 Recommendations for Request No.46 '14” x 20ga  Flat Stock, 10 (FS140)': ['FS300 - 10 FT', 'FS100 - 10 FT', 'FS600 - 10 FT', 'FS200 - 10 FT', 'FS400 - 10 FT', 'ANGL 4 X 10 (20G)', 'ANGL 1.5 X 10 (14G)', 'ANGL 4 X 10 (16G)', 'ANGL 3 X 10 (16G)', 'H14']
# Top-10 Recommendations for Request No.47 '150plalam (TNH  ': ['TOP 150', 'CB125 120PLUS - 10 FT', 'CB125 120PLUS - 8 FT', 'CB125 120PLUS - 12 FT', 'ATH29', 'GTM', 'TCH', 'CS75-150-150 A', 'SOH-33', 'SOH-66']
# Top-10 Recommendations for Request No.48 '190esselml onout 165 woow outerof car liquid  ': ['ACUT-75-78 - 10 FT', 'ACOF-100-75 - 10 FT', 'ACOF-78-50 - 10 FT', 'ACOF-78-100 - 10 FT', 'ACOF-78-75 - 10 FT', 'ACOF-78-150 - 10 FT', 'ACOF-75-75 - 10 FT', 'CBS200-16WW - 10 FT', 'CBS200-332WW - 10 FT', 'CBS150-332WW - 10 FT']
# Top-10 Recommendations for Request No.49 '190essel ]': ['NAME', 'LEHJG', 'CDLMS33G', 'CDLMS30G', 'CDLMS24G', 'CDLMS21G', 'CDLMS18G', 'CDLMS15G', 'CDLMS12G', 'CDLDS48G']
# Top-10 Recommendations for Request No.50 '2 x 4 Fire Treated': ['ANGL 2 X 4-16', 'ANGL 2 X 4-14', 'ANGL 2 X 4 16GA', 'CORNERITE - 2 IN X 2 IN X 4FT', 'ANGL 2 X 4 (18G)', 'ANGL 2 X 4.5-20', 'ANGL 2 X 4 (12GA)', 'DZF 2 X 4 X 2-16GA', 'DZF 2 X 4 X 2-20GA', 'ANGL 2 X 4 (25GA)']
# Top-10 Recommendations for Request No.51 '2-1/2': ['VFL 2-1/2 X 2-1/2 - 10 FT', 'STRUCTURAL STUD 2-1/2IN 16G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 18G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 14G 2-1/2IN FL', 'STR TRACK 2-1/2IN 20G 2-1/2IN LEGS', 'STR TRACK 2-1/2IN 16G 2-1/2IN LEGS', 'STRUCTURAL STUD 2-1/2IN 12G 2-1/2IN FL', 'STR TRACK 2-1/2IN 18G 2-1/2IN LEGS', 'VFLE 2-1/2 X 2-1/2 - 10 FT', 'STR TRACK 2-1/2IN 14G 2-1/2IN LEGS']
# Top-10 Recommendations for Request No.52 '2-1/2  21 ii r'^ equip (ION SEEK OST temp gi PCa Gas  ': ['VFL 2-1/2 X 2-1/2 - 10 FT', 'STRUCTURAL STUD 2-1/2IN 16G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 18G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 14G 2-1/2IN FL', 'STR TRACK 2-1/2IN 20G 2-1/2IN LEGS', 'STR TRACK 2-1/2IN 16G 2-1/2IN LEGS', 'STRUCTURAL STUD 2-1/2IN 12G 2-1/2IN FL', 'STR TRACK 2-1/2IN 18G 2-1/2IN LEGS', 'VFLE 2-1/2 X 2-1/2 - 10 FT', 'STR TRACK 2-1/2IN 14G 2-1/2IN LEGS']
# Top-10 Recommendations for Request No.53 '2-1/2' x 20ga Int Stud (sizes 2) (S  ': ['VFL 2-1/2 X 2-1/2 - 10 FT', 'STRUCTURAL STUD 2-1/2IN 16G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 18G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 14G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 12G 2-1/2IN FL', 'STR TRACK 2-1/2IN 20G 2-1/2IN LEGS', 'VFLE 2-1/2 X 2-1/2 - 10 FT', 'STR TRACK 2-1/2IN 16G 2-1/2IN LEGS', 'STR TRACK 2-1/2IN 18G 2-1/2IN LEGS', 'STR TRACK 2-1/2IN 14G 2-1/2IN LEGS']
# Top-10 Recommendations for Request No.54 '2  ]': ['2-1/2IN BLAZEFRAME RIPTRAK 2HR 2IN 20G', '2-1/2IN BLAZEFRAME RIPTRAK 2HR 2IN 16G', '2-1/2IN BLAZEFRAME RIPTRAK 2HR 2IN 18G', '2-1/2IN BLAZEFRAME RIPTRAK 2HR 2IN 14G', '2-1/2IN BF SW RIPTRAK 2HR 2IN 20G', '2-1/2IN BF SW RIPTRAK 2HR 2IN 16G', '2-1/2IN BF SW RIPTRAK 2HR 2IN 18G', '2-1/2IN BF SW RIPTRAK 2HR 2IN 14G', 'STRUCTURAL STUD 2-1/2IN 16G 2-1/2IN FL', 'STRUCTURAL STUD 2-1/2IN 18G 2-1/2IN FL']
# Top-10 Recommendations for Request No.55 '2’ x 4' (CBB58)': ['FB58-10', 'VLCB -  1-1/4 X 10 FT (CB125)', 'VLCB - 1-1/4 X 8 FT (CB125)', 'VLSB -  10FT (CB125 120)', 'VLSB - 8 FT (CB125 120)', 'JB58 - 8 FT', 'MJB58-10', 'DCB58-25 - 10 FT', 'MJB58-8', 'BJB58 - 10 FT']
# Top-10 Recommendations for Request No.56 '2’ x 6  ': ['ANGL 2 X 6-16', 'ANGL 2 X 6-14', 'ANGL 2 X 6-12', 'CDMB 2 X 6', 'CDBV 2 X 6', 'ANGL 3 X 6-16', 'ANGL 4 X 6-16', 'CDMB 4 X 6', 'ANGL 3 X 6-18', 'ANGL 4 X 6-18']
# Top-10 Recommendations for Request No.57 '2x ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['#2X - 10 FT', 'TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', '#2X - 8 FT', 'STOCK-AID II 2 1/2 INX2 1/2 INX10FT', 'ANGL 2X2-14GA', 'ANGL 2X2-12GA', '#2X ARCH - 10 FT', 'LHJT (L)']
# Top-10 Recommendations for Request No.58 '2x6  ': ['QTWS6X6', '#2X - 10 FT', 'QTWS3 5X6', 'ECC4X4X6-68', 'ECC4X4X6-54', '#2X - 8 FT', 'STOCK-AID II 2 1/2 INX2 1/2 INX10FT', '#2X ARCH - 10 FT', 'ANGL 2X2-14GA', 'ANGL 2X2-12GA']
# Top-10 Recommendations for Request No.59 '2x ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['#2X - 10 FT', 'TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', '#2X - 8 FT', 'STOCK-AID II 2 1/2 INX2 1/2 INX10FT', 'ANGL 2X2-14GA', 'ANGL 2X2-12GA', '#2X ARCH - 10 FT', 'LHJT (L)']
# Top-10 Recommendations for Request No.60 '4 strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', '3.4 STRIP LATH GROOVED 23 INX 8FT', 'LHJT (L)', 'LHJT (R)', '10FT VINYL 1/2IN L TRIM W/TEAR STRIP', 'STRIP LATH - 4 IN X 8FT', '3/4 IN J-TRIM W/W 3-1/2 IN FLG', 'STRIP LATH - 6 IN X 8FT', 'WSR']
# Top-10 Recommendations for Request No.61 '3-1 weil veil dub dich ti ii r'^ equip (ION SEEK OST temp gi PCa Gas  ': ['STRUCTURAL STUD 3-1/2IN 16G 3-1/2IN FL', 'OSR', 'PC46', '3-1/2IN Z-GIRT 18G', '3-1/2IN Z-GIRT 20G', '3-1/2IN Z-GIRT 16G', '3-1/2IN Z-GIRT 14G', 'VFLC 3-1/2 X 3-1/2 - 10 FT', '3-1/2IN Z-GIRT 18G 8FT', 'STRUCTURAL STUD 3-5/8IN 16G 3-1/2IN FL']
# Top-10 Recommendations for Request No.62 '3-5/8' x 20ga Int Stud (sizes 7) (S  ': ['STRUCTURAL STUD 3-5/8IN 20G 1-5/8IN FL', 'DRYWALL TRACK 3-5/8IN 20G 3-5/8IN LEGS', 'STRUCTURAL STUD 3-5/8IN 16G 1-5/8IN FL', 'STR TRACK 3-5/8IN 18G 3-5/8IN LEGS', 'STRUCTURAL STUD 3-5/8IN 18G 1-5/8IN FL', 'STRUCTURAL STUD 3-5/8IN 14G 1-5/8IN FL', 'STRUCTURAL STUD 3-5/8IN 12G 1-5/8IN FL', 'STRUCTURAL STUD 3-5/8IN 10G 1-5/8IN FL', 'STR TRACK 3-5/8IN 20G 1-5/8IN LEGS', 'STR TRACK 3-5/8IN 16G 1-5/8IN LEGS']
# Top-10 Recommendations for Request No.63 '3  ]': ['STRUCTURAL TRACK 3-3/4IN 20G 3IN LEGS', 'STR TRACK 3-5/8IN 20G 3-3/4IN LEGS', 'STR TRACK 3-5/8IN 18G 3-3/4IN LEGS', 'VFL 3 X 3 - 10 FT', 'DZF 3 X 3 X 3 -16G', 'STRUCTURAL TRACK 3-1/2IN 20G 3IN LEGS', 'STRUCTURAL TRACK 3-1/2IN 16G 3IN LEGS', 'STRUCTURAL TRACK 3-1/2IN 18G 3IN LEGS', 'STRUCTURAL TRACK 3-5/8IN 20G 3IN LEGS', 'STRUCTURAL TRACK 3-1/2IN 14G 3IN LEGS']
# Top-10 Recommendations for Request No.64 '3’ (PLY  ': ['SPL-PLT SPLICE PLATE', 'VENEER PLSTR BEAD (KAL-KORNER)', '3.5IN x 3.5IN 25G G40 33KSI DANBACK® PL', 'ANGL 3 X 3 (14G)', '3.5IN x 5.5IN 25G G40 33KSI DANBACK® PL', 'ANGL 3 X 3 (12GA)', 'ANGL 3 X 3-33(20G)', 'ANGL 3 X 3-54(16G)', 'DZF 3 X 3 X 3 (18G)', 'ANGL 3 X 3-30(20G)']
# Top-10 Recommendations for Request No.65 '3” 11/8\" (PWD136FT)': ['PB6', 'STRUCTURAL TRACK 3-11/16IN 18G 1.5IN LEG', 'STRAP 11-5/8 IN (20G)', 'STRUCTURAL TRACK 3-11/16IN 16G 1.5IN LEG', 'HEMMED H-STUD 11/16 LEG', 'UNHEMMED H-STUD 11/16 LEG', 'STRAP 11 (16G)', 'ANGL 1 3/8 X 7/8-18(25GA)', 'ANGL 1 3/8 X 7/8-30(20GA)', 'CB138E - 8 FT']
# Top-10 Recommendations for Request No.66 '3isserail temp gi PCa Gas  ': ['PC46', 'PC44R', '1550A', '3IN Z-GIRT 18G', '3IN Z-GIRT 20G', '3IN Z-GIRT 16G', '3IN Z-GIRT 14G', '3-1/2IN Z-GIRT 18G', '3-1/2IN Z-GIRT 20G', '3-1/2IN Z-GIRT 16G']
# Top-10 Recommendations for Request No.67 '374 rail temp gi PCa Gas  ': ['RAIL BRACKET', 'PC46', 'PC44R', 'CDTPA4', 'ISU2.37/16', 'ISU2.37/14', 'TRS2.37/16', 'TRS2.37/14', 'MA4', 'RSV2.37/16']
# Top-10 Recommendations for Request No.68 '40of car liquid  ': ['#40 - 10 FT', '#40 - 8 FT', '#40 - 12 FT', '#40-10 UPC', '#40 - 9 FT', '#40 - 7 FT', 'ACOF-100-75 - 10 FT', 'ACOF-78-50 - 10 FT', 'ACOF-78-100 - 10 FT', 'ACOF-78-75 - 10 FT']
# Top-10 Recommendations for Request No.69 '400  ]': ['TOP 400', 'CONNECTOR 400', 'CS58-400C', 'CS50-400C', 'CS58-400T', 'CS50-400T', 'CS58-400A', 'CS50-400A', 'CS58-400OC', 'CS58-400EC']
# Top-10 Recommendations for Request No.70 '4’ GPDGTBB58)': ['GP8-10PK', 'GP5-10PK', '6658BB R - 10FT', 'DFL58-25BB - 10FT', 'DFL75-25BB', 'MITEK LUGT1 TIEDOWN', 'TCD', 'DFL100-25BB - 10FT', '6678BB R - 10FT', 'D-6678BB - 10FT']
# Top-10 Recommendations for Request No.71 '4“  ': ['STR TRACK 4-3/4IN 18G 1-1/4IN LEGS', 'STR TRACK 4-1/4IN 16G 1-1/4IN LEGS', 'STR TRACK 4-1/4IN 18G 1-1/4IN LEGS', 'STRUCTURAL TRACK 4IN 20G 4IN LEGS', 'STRUCTURAL TRACK 4IN 18G 4IN LEGS', 'STRUCTURAL TRACK 4IN 16G 1-1/4IN LEGS', 'STRUCTURAL TRACK 4IN 20G 1-1/4IN LEGS', 'STRUCTURAL TRACK 4IN 18G 1-1/4IN LEGS', 'BC5-1/4-4', 'STRUCTURAL TRACK 4IN 14G 1-1/4IN LEGS']
# Top-10 Recommendations for Request No.72 '5 dB ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['TILE CAP', 'UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'LHJT (L)', 'LHJT (R)', 'CIWT-350 DBR - 10FT', '10FT VINYL 1/2IN L TRIM W/TEAR STRIP', 'CJV16-C', 'PLASTIC 3 WAY CORNER CAP 1-1/2 IN', 'CJV-16E-C']
# Top-10 Recommendations for Request No.73 '5-1/ easure dB ail utc G C Cap strip Carrier/an ausbeit  ( whe I UC UC devices  ': ['STR TRACK 5-1/2IN 20G 1-1/4IN LEGS', 'STR TRACK 5-1/2IN 16G 1-1/4IN LEGS', 'STR TRACK 5-1/2IN 18G 1-1/4IN LEGS', 'EA66', 'STR TRACK 5-1/2IN 14G 1-1/4IN LEGS', 'STR TRACK 5-1/2IN 12G 1-1/4IN LEGS', 'STR TRACK 5-1/2IN 20G 1-1/2IN LEGS', 'STR TRACK 5-1/2IN 16G 1-1/2IN LEGS', 'STR TRACK 5-1/2IN 18G 1-1/2IN LEGS', 'EA44']
# Top-10 Recommendations for Request No.74 '5” 8\" Backer Board (X58)': ['#1A CORNERBEAD (X1)', '#1A IRREGULAR CORNERBEAD (X1)', 'WOOD TOP BOARD 41IN', 'HANGER WIRE (12G)', 'WOOD BTM BOARD 41 IN', 'WOOD BTM BOARD 37.5 IN', 'ANGL 5 X 5 (12G)', 'ANGL 1.5 X 8 (20G)', 'ANGL 8 X 8 (16G)', 'ANGL .5 X 1.5 (20G)']
# Top-10 Recommendations for Request No.75 '5“  Gas  ': ['ANGL 5.5 X 5.5 -18G', 'ANGL 1.5 X 5.5-16', 'STRAP 5.5-16GA', 'STRAP 5.5-14GA', 'ANGL 1.5 X 5-16', 'ANGL 2.5 X 5.5-68 (14GA)', 'STRAP 5.5 IN 12GA', 'STRAP 5.5 (18G)', 'ANGL 5 X 5-18GA', 'ANGL 1.5 X 5-20GA']
# Top-10 Recommendations for Request No.76 '50 rail temp gi PCa Gas  ': ['TOP 50', 'RAIL BRACKET', 'PC46', 'PC44R', 'CS50-50A', 'CS58-50A', 'DR50-50A', 'CS75-50A', 'DR58-50A', 'CS38-50A']
# Top-10 Recommendations for Request No.77 '508of car liquid  ': ['TOP 50', 'ACOF-78-50 - 10 FT', '5078-50-10', 'ACOF-100-75 - 10 FT', 'ACOF-78-100 - 10 FT', 'ACOF-78-75 - 10 FT', 'ACOF-78-150 - 10 FT', 'ACOF-75-75 - 10 FT', '1558R-50 A', '1578-50 - 10 FT']
