# %%
import pytesseract
from PIL import Image
import pdf2image
from huggingface_hub import InferenceClient
import json
import re
import pandas as pd
from transformers import BertTokenizer
import fasttext
import fasttext.util
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
fasttext.util.download_model('en', if_exists='ignore')  # Download English model
ft_model = fasttext.load_model('cc.en.300.bin')

# %%
API_TOKEN = "hf_xxxxx" # replace with your API token

client = InferenceClient(
    model="meta-llama/Meta-Llama-3.1-8B-Instruct",
    token=API_TOKEN,
)

# %%
def OCR_extraction(pages):
    # Extract text from image
    text = []
    for page in pages:
        text.append(pytesseract.image_to_string(page))
    return text

def extract_line_items_llama(text):
    prompt_template = """Here's my OCR output from a pdf doc for the purpose of industrial quote generation. 
                        Generate a json file containing list of industrial product_name alphabetical only without special characters 
                        (eg. "Corner Bead paper faced 10"; "5 8 Firecode Core"; "Easy Clip S545") 
                        based on the parsed output (use common sense and imagining the parsed format from a table where related information may be parsed in separate lines), 
                        ignore the quantity (eg. 35,288.66) and unit (eg. 1,000 LF or 1,000 SF or 37.00 EA) in the parsed text:
                        
                        Only output something like this structured output without explanation and code:
                        [
                            {{ "product": "Product A"}},
                            {{ "product": "Product B"}},
                            {{ "product": "Product C"}}, 
                            ...
                        ]:
                        
                        {text}
                        """
    prompt = prompt_template.format(text=text)
    messages = [{"role": "system", "content": "You are a bot that responds only with the extracted product list."},
                {"role": "user", "content": prompt}]
    print("Waiting for Meta-Llama-3.1-8B-Instruct to generate output...")
    response = client.chat_completion(
        messages=messages,
        max_tokens=1520,
        stream=True,
        temperature=0.0,
    )

    structured_line_items = ""
    for message in response:
        structured_line_items += message.choices[0].delta.content
    
    return structured_line_items.strip()


def extract_product_names(structured_line_items_str):
    try:
        # Use a regular expression to extract the product names
        product_names = re.findall(r'"product":\s*"(?:[^"\\]|\\.)*"', structured_line_items_str)
        # Remove the "product": and quotes from the matches
        product_names = [match[12:-1] for match in product_names]
        return product_names
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return None

# %%
# Convert PDF to images
request_1 = pdf2image.convert_from_path('/Users/evanwyf/Downloads/AutoQuote/Data/Request-Response 1/Request 1.pdf')
request_2 = pdf2image.convert_from_path('/Users/evanwyf/Downloads/AutoQuote/Data/Request-Response 2/Request 2.pdf')
product_db = pd.read_csv('/Users/evanwyf/Downloads/AutoQuote/Data/ProductDB.csv')

# Extract text from each image
text = OCR_extraction(request_2)
# Combine the extracted text into a single string
combined_text = " ".join(text)

# Extract the line items from the combined text
structured_line_items_str = extract_line_items_llama(combined_text)
if structured_line_items_str:
    print("Extracted Items:", structured_line_items_str)
    product_names = extract_product_names(structured_line_items_str)
    product_names = [name for name in product_names if len(name) > 4] # Filter out short product names
    print("# of extracted products:", len(product_names))

    # Load the product database
    product_names_db = product_db.iloc[:, 2].tolist()  # Assuming the product name is in the third column
    print("# of DB products:", len(product_names_db))
    # Initialize BERT tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Waiting for Meta-Llama-3.1-8B-Instruct to generate output...
# Extracted Items: [
#   { "product": "Easy Clip S545" },
#   { "product": "Uni-Clip UCEC" },
#   { "product": "Extended FastClip FCEC12" },
#   { "product": "Extended FastClip FCEC8" },
#   { "product": "2 16ga Flat Strapping FS216" },
#   { "product": "10 x 2 x 16ga Ext Stud S1000S200-54" },
#   { "product": "2-1/2 x 2 x 16ga Ext Stud S250S200-54" },
#   { "product": "3-5/8 x 1-5/8 x 16ga Ext Stud S362S162-54" },
#   { "product": "4 x 1-5/8 x 18ga Ext Stud S400S162-43" },
#   { "product": "4 x 1-5/8 x 16ga Ext Stud S400S162-54" },
#   { "product": "4 x 2 x 16ga Ext Stud S400S200-54" },
#   { "product": "6 x 1 5/8 x 16ga Ext Stud S600S162-54" },
#   { "product": "6 x 2 x 16ga Ext Stud S600S200-54" },
#   { "product": "8 x 1-5/8 x 16ga Ext Stud S800S162-54" },
#   { "product": "2-1/2 x 16ga Ext Track T250T125-54" },
#   { "product": "3-5/8 x 16ga Ext Track T362T125-54" },
#   { "product": "4 x 18ga Ext Track T400T125-43" },
#   { "product": "4 x 16ga Ext Track T400T125-54" },
#   { "product": "6 x 16ga Ext Track T600T125-54" },
#   { "product": "8 x 16ga Ext Track T800T125-54" },
#   { "product": "Gyp Screws DTS178" },
#   { "product": "Jek Points PHTLATH" },
#   { "product": "3/4 Concrete Ptwioad SPC" },
#   { "product": "Roof Blocking Screw RBS3" },
#   { "product": "Roof Plywood Screw RPS2" },
#   { "product": "Gyp Sheathing Screw DTX114" },
#   { "product": "Chicago Metallic 640 Dw Grid Main Runner CM640" },
#   { "product": "Chicago Metallic Dw Grid 4' Tee CM644" },
#   { "product": "Hanger Wire HW12-EA" },
#   { "product": "1-5/8 25ga Track as Molding T15825CLG" },
#   { "product": "5/8 Cement Backer Board CBB58" },
#   { "product": "5/8 Dens-Shield Tile Backer Board GPDGTBB58" },
#   { "product": "5/8 Fire Rated Gypsum Board X58" },
#   { "product": "5/8 Fire Rated XP Gypsum Board X58XP" },
#   { "product": "Acoustical Sealant ACTSEAL290Z" },
#   { "product": "Sound Batt Insulation SB1116" },
#   { "product": "Sound Batt Insulation SB1916" },
#   { "product": "Clip Angle CL2320" },
#   { "product": "6 20ga Flat Stock FS620" },
#   { "product": "Spazzer Bar bridging SPAZZER" },
#   { "product": "7/8 20ga Furring Channel FC7820" },
#   { "product": "2-1/2 x 20ga Int Stud S21220-33M" },
#   { "product": "3-5/8 x 20ga Int Stud S35820-33M" },
#   { "product": "6 x 20ga Int Stud S620-33M" },
#   { "product": "2-1/2 x 20ga Int Track T21220-33M" },
#   { "product": "2-1/2 20ga Slotted Deflection Track T21220SLOT-33" },
#   { "product": "3-5/8 x 20ga Int Track T35820-33M" },
#   { "product": "3-5/8 20ga Int Slotted Deflection Track T35820SLOT-33" },
#   { "product": "6 x 20ga Int Track T620-33M" },
#   { "product": "6 20ga Slotted Deflection Track T620SLOT-33" },
#   { "product": "5/8 Cement Board Sheathing CBSHEATHS58" },
#   { "product": "1/2 Dens-Deck Sheathing GPDD12" },
#   { "product": "5/8 Dens-Glass Gold Sheathing GPDGG58" },
#   { "product": "Durabond Easy Sand Setting Compound DURABONDES" },
#   { "product": "Tape 250' Roll TAPE-250" },
#   { "product": "Taping Compound TFCMPND" },
#   { "product": "6 Mill Poly POLY6M" },
#   { "product": "Corner Bead CB10" },
#   { "product": "Control Joint CJ093" },
#   { "product": "1/2 tearaway plastic L bead TEARAWAY12" },
#   { "product": "2x4 Fire Treated 204FT" },
#   { "product": "2x6 Fire Treated 206FT" },
#   { "product": "2x8 Fire Treated 208FT" },
#   { "product": "1/2 CDX F/R Plywood PLY12FT" },
#   { "product": "3/4 CDX Fire-treated Plywood PLY34FT" },
#   { "product": "3/4 T&G Underlayment PLY34UNDTG" },
#   { "product": "5/8 fire treated plywood PLY58FT" },
#   { "product": "2x4 Pressure Treated Roof Blocking 204PTRF" },
#   { "product": "2x6 Pressure Treated Roof Blocking 206PTRF" },
#   { "product": "2x8 Pressure Treated Roof Blocking 208PTRF" },
#   { "product": "2x4 Pressure Treated Window Blkg 204PTW" },
#   { "product": "2x6 Pressure Treated Window Bikg 206PTW" },
#   { "product": "2x8 Pressure Treated Window Blkg 208PTW" },
#   { "product": "1/2 CDX Pressure treated Plywood PLY12PTW" },
#   { "product": "3/4 CDX Pressure treated Plywood PLY34PTW" }
# ]
# # of extracted products: 75
# # of DB products: 9813
# /Users/evanwyf/miniconda3/envs/auto_quote/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def custom_tokenize(text, tokenizer):
    # Use BERT tokenizer to tokenize text
    tokens = tokenizer.tokenize(text)
    return tokens

def compute_similarity_scores_fasttext(extracted_names, product_names, tokenizer, model):
    # Tokenize and vectorize product names using BERT tokenizer
    extracted_vectors = []
    for name in extracted_names:
        tokens = custom_tokenize(name, tokenizer)
        vectors = [model.get_word_vector(token) for token in tokens]
        extracted_vectors.append(np.mean(vectors, axis=0))
    
    product_vectors = []
    for name in product_names:
        tokens = custom_tokenize(name, tokenizer)
        vectors = [model.get_word_vector(token) for token in tokens]
        product_vectors.append(np.mean(vectors, axis=0))
    
    # Compute cosine similarity scores
    similarity_scores = cosine_similarity(np.array(extracted_vectors), np.array(product_vectors))
    
    return similarity_scores

def get_top_n_recommendations_fasttext(similarity_scores, product_names, n=10):
    recommendations = []
    for scores in similarity_scores:
        # Get the indices of the top-n scores
        top_indices = scores.argsort()[-n:][::-1]
        top_recommendations = [product_names[i] for i in top_indices]
        recommendations.append(top_recommendations)
    return recommendations

# %%
# Compute similarity scores using FastText with BERT tokenizer
similarity_scores = compute_similarity_scores_fasttext(product_names, product_names_db, tokenizer, ft_model)

# Get top-10 recommendations for each extracted product name
top_10_recommendations = get_top_n_recommendations_fasttext(similarity_scores, product_names_db)
for i, recommendations in enumerate(top_10_recommendations):
    print(f"Top-10 Recommendations for '{product_names[i]}': {recommendations}")
# Out:
# Top-10 Recommendations for 'Easy Clip S545': ['S414', 'S610', 'S310', 'MITEK S/PHD4', 'MITEK S/PHD9', 'MITEK S/PHD6', 'T12', 'TGHW4', 'TPA4G', 'NP-S']
# Top-10 Recommendations for 'Uni-Clip UCEC': ['UCEC UNICLIP END CLIP', 'UCEC UNICLIP END CLIP', 'MP-UNMT', 'UNI-TRACK - 8FT', 'UNI-TRACK - 10 FT', 'FLAT DIAMOND SECURITY LATH - CDBS-SL', 'RCK-MNT-BKT L PLATE MID CHASSIS X STRONG', 'DS/DR58-FWS6678 NW-10', 'UXRC12 UNICLIP EXT RIGID CLIP', 'UXRC10 UNICLIP EXT RIGID CLIP']
# Top-10 Recommendations for 'Extended FastClip FCEC12': ['FCS58-100EC', 'FCS25-100EC', 'FCS75-100EC', 'FCS38-100EC', 'FCS58-200EC', 'FCS58-150EC', 'FCS25-200EC', 'FCS25-150EC', 'FCS75-150EC', 'FCS75-200EC']
# Top-10 Recommendations for 'Extended FastClip FCEC8': ['FCS78-100EC', 'FCS78-150EC', 'FCS75-100EC', 'FCS78-200EC', 'FCS58-100EC', 'FCS75-150EC', 'FCS58-150EC', 'FCS25-100EC', 'FCS25-150EC', 'FCS58-200EC']
# Top-10 Recommendations for '2 16ga Flat Strapping FS216': ['FSB125-3IN 20G FLATSTRAPBACKER 1.25 TAPE', 'ProTRAK 22MIL-33EQ 2-1/2 DW TRACK 2 LEG', 'ProTRAK 22MIL-33EQ 6 DW TRACK 2-1/2 LEG', 'NOTCH TRK 4IN 16G 1IN LEGS 16IN OC', 'ProTRAK 33MIL 4IN DW TRACK 2-1/2IN LEG', 'ProTRAK 33MIL 1-5/8IN DW TRACK 2IN LEG', 'ProTRAK 22MIL-33EQ 1-5/8 DW TRACK 2 LEG', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 2 LEG', 'ProTRAK 22MIL-33EQ 4 DW TRACK 1-1/2 LEG', 'ProTRAK 22MIL-33EQ 4 DW TRACK 1-1/4 LEG']
# Top-10 Recommendations for '10 x 2 x 16ga Ext Stud S1000S200-54': ['#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', 'DZF 3 X 3 X 3 -16G', 'DZF 2 X 4 X 2-16GA', 'DZF 2 X 2 X 2 -20G 33MIL', 'DZF 2 X 4 X 2-20GA', 'DZF 2 X 3 X 2-20GA', 'DZF 2 X 2 X 2-14GA', 'X689  2 X 2 X 9-3/4  (14G) PUNCHED', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', 'X683   2 X 2 X 3-3/8 (14G) PUNCHED']
# Top-10 Recommendations for '2-1/2 x 2 x 16ga Ext Stud S250S200-54': ['S681 SUPPORT CLIP 14G 1-1/2 X 1-1/2 X 11', 'S547 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 7', 'S541 SUPPORT CLIP 16G 1-1/2 X 1-1/2 X 11', 'S971 SUPPORT CLIP 12G 1-1/2 X 1-1/2 x 11', 'S979 SUPPORT CLIP 12GA 1-1/2 X 1-1/2 X 9', 'S689 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 9', 'S545 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 5', 'S687 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 7', 'S683 SUPPORT CLIP 14GA 1-1/2 X 1-1/2 X 3', 'S543 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 3']
# Top-10 Recommendations for '3-5/8 x 1-5/8 x 16ga Ext Stud S362S162-54': ['362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC2-54 - 3-5/8 X 1-1/2 X 2 - 16G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '362BHC2-43 - 3-5/8 X 1-1/2 X 2 - 18G', '362BHC4-54 - 3-5/8 X 1-1/2 X 4 - 16G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G']
# Top-10 Recommendations for '4 x 1-5/8 x 18ga Ext Stud S400S162-43': ['362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', '362BHC4-43 - 3-5/8 X 1-1/2 X 4 - 18G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC2-43 - 3-5/8 X 1-1/2 X 2 - 18G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '800BHC6-43 - 8 X 1-1/2 X 6 - 18G', '362BHC6-68 - 3-5/8 X 1-1/2 X 6 - 14G']
# Top-10 Recommendations for '4 x 1-5/8 x 16ga Ext Stud S400S162-54': ['362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC4-54 - 3-5/8 X 1-1/2 X 4 - 16G', '362BHC6-68 - 3-5/8 X 1-1/2 X 6 - 14G', '362BHC8-68 - 3-5/8 X 1-1/2 X 8 - 14G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G']
# Top-10 Recommendations for '4 x 2 x 16ga Ext Stud S400S200-54': ['DZF 2 X 4 X 2-16GA', 'DZF 3 X 3 X 3 -16G', 'DZF 2 X 2 X 2-14GA', 'X689  2 X 2 X 9-3/4  (14G) PUNCHED', 'DZF 2 X 4 X 2-20GA', 'X549   2 X 2 X 9-3/4 (16G) PUNCHED', 'DZF 2 X 2 X 2 -20G 33MIL', 'X687  2 X 2 X 7-3/4  (14G) PUNCHED', 'X683   2 X 2 X 3-3/8 (14G) PUNCHED', 'DZF 2 X 2 X 2 -18G']
# Top-10 Recommendations for '6 x 1 5/8 x 16ga Ext Stud S600S162-54': ['1-5/8 X 12 STEEL STUD 20G', '3-5/8 X 9 STEEL STUD 20G', '3-5/8 X 14 STEEL STUD 20G', '3-5/8 X 12 STEEL STUD 20G', '3-5/8 X 9 STEEL STUD 25G', 'DFC 7/8 X 1-1/4 X 7/8 (12G)', '#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '2-1/2 X 12 STEEL STUD 20G', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', 'STRUCTURAL BLOCKING - 8 X 15-3/4 16G']
# Top-10 Recommendations for '6 x 2 x 16ga Ext Stud S600S200-54': ['DZF 2 X 4 X 2-16GA', 'DZF 3 X 3 X 3 -16G', 'DZF 2 X 2 X 2-14GA', 'X689  2 X 2 X 9-3/4  (14G) PUNCHED', 'DZF 2 X 4 X 2-20GA', 'DZF 2 X 2 X 2 -20G 33MIL', 'X549   2 X 2 X 9-3/4 (16G) PUNCHED', 'X683   2 X 2 X 3-3/8 (14G) PUNCHED', 'X687  2 X 2 X 7-3/4  (14G) PUNCHED', 'DZF 2 X 2 X 2 -18G']
# Top-10 Recommendations for '8 x 1-5/8 x 16ga Ext Stud S800S162-54': ['362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', '362BHC8-68 - 3-5/8 X 1-1/2 X 8 - 14G', '800BHC10-54 - 8 X 1-1/2 X 10 - 16G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '800BHC6-54 - 8 X 1-1/2 X 6 - 16G']
# Top-10 Recommendations for '2-1/2 x 16ga Ext Track T250T125-54': ['U683 1-1/2 X 1-1/2 X 3-3/8 (14G) PUNCHED', 'U689 1-1/2 X 1-1/2 X 9-3/4 (14G) PUNCHED', 'U687 1-1/2 X 1-1/2 X 7-3/4 (14G) PUNCHED', 'U549 1-1/2 X 1-1/2 X 9-3/4 (16G) PUNCHED', 'U547 1-1/2 X 1-1/2 X 7-3/4 (16G) PUNCHED', 'U973 1-1/2 X 1-1/2 X 3-3/8 (12G) PUNCHED', 'U685 1-1/2 X 1-1/2 X 5-3/4 (14G) PUNCHED', 'S681 SUPPORT CLIP 14G 1-1/2 X 1-1/2 X 11', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', 'U979 1-1/2 X 1-1/2 X 9-3/4 (12G) PUNCHED']
# Top-10 Recommendations for '3-5/8 x 16ga Ext Track T362T125-54': ['362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G', '362BHC8-68 - 3-5/8 X 1-1/2 X 8 - 14G', '362BHC6-68 - 3-5/8 X 1-1/2 X 6 - 14G', '362BHC4-54 - 3-5/8 X 1-1/2 X 4 - 16G']
# Top-10 Recommendations for '4 x 18ga Ext Track T400T125-43': ['#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', 'DZF 1.25 x 3 x 1.25 -16G', 'DZF 3 X 3 X 3 -16G', 'DZF 2 X 2 X 2 -20G 33MIL', '#40 2PC EXP JOINT 1/2 X 10FT - ZINC', 'DZF .75 X 3.5 X 1.25 -16G', 'DZF 2 X 4 X 2-16GA', 'DZF 1.5 X 3 X 1.5 -16GA', '#40 EXP JOINT 3/4 X 10FT']
# Top-10 Recommendations for '4 x 16ga Ext Track T400T125-54': ['#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', 'DZF 1.25 x 3 x 1.25 -16G', '#40 2PC EXP JOINT 1/2 X 10FT - ZINC', 'DZF 3 X 3 X 3 -16G', 'DZF 2 X 2 X 2 -20G 33MIL', 'DZF .75 X 3.5 X 1.25 -16G', 'DZF 2 X 4 X 2-16GA', 'DZF 1.5 X 3 X 1.5 -16GA', '#40 EXP JOINT 3/4 X 10FT']
# Top-10 Recommendations for '6 x 16ga Ext Track T600T125-54': ['#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', '701-B(L) VENEER TRIM 5/8 IN X 8FT', '701-A(J) VENEER TRIM 5/8 IN X 8FT', '801-B(L) VENEER TRIM 5/8 IN X 8FT', '701-B(L) VENEER TRIM 5/8 IN X 10FT', 'DZF 1.25 x 3 x 1.25 -16G', '801-A(J) VENEER TRIM 5/8 IN X 8FT', '801-B(L) VENEER TRIM 5/8 IN X 10FT', 'DFL150-25BB-SL 38 - 10FT']
# Top-10 Recommendations for '8 x 16ga Ext Track T800T125-54': ['#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '#40 2PC EXP JOINT 3/4 X 10FT - ZINC', '701-B(L) VENEER TRIM 5/8 IN X 8FT', '701-A(J) VENEER TRIM 5/8 IN X 8FT', '801-B(L) VENEER TRIM 5/8 IN X 8FT', '801-A(J) VENEER TRIM 5/8 IN X 8FT', 'DZF 1.25 x 3 x 1.25 -16G', '701-B(L) VENEER TRIM 5/8 IN X 10FT', '701-A(J) VENEER TRIM 5/8 IN X 10FT', 'DFL150-25BB-SL 38 - 10FT']
# Top-10 Recommendations for 'Gyp Screws DTS178': ['GC1G', 'GF500', 'GDTS 100 SDS-250', 'GDTS 100 SDS-500', 'GDTS 150 SDS-250', 'GDTS 250 SDS-250', 'GDTS 300 SDS-250', 'GDTS 150 SDS-500', 'GDTS 200 SDS-250', 'GDTS 350 SDS-250']
# Top-10 Recommendations for 'Jek Points PHTLATH': ['PHS26', 'PHS26', 'VENEER PLSTR BEAD (KAL-KORNER)', 'TUFF SHED JOIST', 'MA4', 'TUR75-225 T', '8FT GALVANIZED KAL KORNER BEAD', 'TUR75-350 C', 'TUR75-350 T', 'VINYL BULL NOSE KERF /J BEAD']
# Top-10 Recommendations for '3/4 Concrete Ptwioad SPC': ['2-1/2 TRAKLOC DEFLECTION STUD 33 MIL', '2-1/2 TRAKLOC ADJUSTABLE STUD 33 MIL', 'ProTRAK 20 LTD 3-1/2IN DW TR 2-1/2IN LEG', 'STR STD 2-1/2IN 16G 2-1/2IN FL 3/8IN RET', 'ProTRAK 20 LTD 2-1/2IN DW TR 2-1/2IN LEG', 'STR STUD 8IN 14G 2-1/2IN FL 2-1/2IN PNCH', '2-1/2 TRAKLOC DEFLECTION STUD 20G', 'ProTRAK 20 LTD 3-5/8IN DW TR 2-1/2IN LEG', '2-1/2 TRAKLOC INSERT 20G', 'ProTRAK 20 LTD 3-1/2IN DW TR 1-1/4IN LEG']
# Top-10 Recommendations for 'Roof Blocking Screw RBS3': ['CBR125A - 10 FT', 'CBR125A - 8 FT', 'CB125A - 10 FT', 'CB125 - 10 FT', 'CB125A - 12 FT', 'CB138E - 10 FT', '10FT PAPER FACED OUTSIDE SUPERWIDE CB', 'CB158E - 10 FT', 'CB125A - 8 FT', 'CB125 - 12 FT']
# Top-10 Recommendations for 'Roof Plywood Screw RPS2': ['R212', 'R214', 'R46', 'R28', 'R26', 'R48', 'R38', 'R216', 'BDX SLOC P/F TP-ON BULNS OUT', 'RH412']
# Top-10 Recommendations for 'Gyp Sheathing Screw DTX114': ['GC1G', 'GF500', 'BDX SLOC P/F TP-ON BULNS OUT', 'GDTS 100 SDS-250', 'GDTS 100 SDS-500', 'GDTS 150 SDS-250', 'GDTS 350 SDS-250', 'GDTS 250 SDS-250', 'GDTS 150 SDS-500', 'GDTS 200 SDS-250']
# Top-10 Recommendations for 'Chicago Metallic 640 Dw Grid Main Runner CM640': ['DGBM150-75 - 10 FT', 'FS300 - 10 FT', 'MF300-50S', 'MF250-50S', 'FS600 - 10 FT', 'RS300V - 10 FT', 'DGBM150-58 - 10 FT', 'RS300 - 10 FT', 'DZF .875 X .875 X .875 (20G)', '3050 - 10 FT']
# Top-10 Recommendations for 'Chicago Metallic Dw Grid 4' Tee CM644': ['EASYCLIP T975 TALL ANCHOR CL 2 X 4 X 5.5', 'EASYCLIP T975 TALL ANCHOR CL 2 X 4 X 5.5', 'DZF 1 X .75 X 1 16GA', '801-B(L) VENEER TRIM 5/8 IN X 8FT', 'A976 END CLIP (UNP) 12 GA. 3 X 3 X 6', 'A686 END CLIP (UNP) 14 GA. 3 X 3 X 6', '801-B(L) VENEER TRIM 1/2 IN X 8FT', '701-B(L) VENEER TRIM 5/8 IN X 8FT', '701-B(L) VENEER TRIM 1/2 IN X 8FT', '801-B(L) VENEER TRIM 5/8 IN X 10FT']
# Top-10 Recommendations for 'Hanger Wire HW12-EA': ['H214-2', 'HTF214-2', 'H24-2', 'H216-2', 'HTF24-2', 'H214-3', 'HTF216-2', 'H26-2', 'HTF214-3', 'H28-2']
# Top-10 Recommendations for '1-5/8 25ga Track as Molding T15825CLG': ['ProTRAK 25 3-5/8IN DW TRACK 1-1/4IN LEG', 'ProTRAK 20 3-5/8IN DW TRACK 1-1/4IN LEG', 'ProTRAK 25 1-5/8IN DW TRACK 1-1/4IN LEG', 'ProTRAK 25 3-5/8IN DW TRACK 1-1/2IN LEG', 'ProTRAK 20 1-5/8IN DW TRACK 1-1/4IN LEG', 'ProTRAK 20 3-5/8IN DW TRACK 1-1/2IN LEG', 'ProTRAK 25 1-5/8IN DW TRACK 2-1/2IN LEG', 'ProTRAK 25 1-5/8IN DW TRACK 1-1/2IN LEG', 'ProTRAK 25 3-5/8IN DW TRACK 2-1/2IN LEG', 'DW TRACK 3-5/8IN 20G 2-1/2IN LEGS 33MIL']
# Top-10 Recommendations for '5/8 Cement Backer Board CBB58': ['3-5/8IN BF SW RIPTRAK 1HR 4IN 20G', 'TRADEREADY TDJ24 1 3/4 FL 50K 11-1/4 12g', 'TRADEREADY TDJ24 1 3/4 FL 50K 9-1/4 12g', '3-5/8IN BF SW RIPTRAK 1HR 4IN 16G', 'TRADEREADY TDJ24 1 3/4 FL 50K 7-1/4 12g', 'TRADEREADY TDJ24 1 3/4 FL 50K 9-1/4 14g', '3-5/8IN BF SW RIPTRAK 1HR 4IN 14G', 'TRADEREADY TDJ24 1 3/4 FL 50K 7-1/4 16g', '3-5/8IN BF SW RIPTRAK 1HR 3IN 20G', '3-5/8IN BF SW RIPTRAK 2HR 4IN 20G']
# Top-10 Recommendations for '5/8 Dens-Shield Tile Backer Board GPDGTBB58': ['GP5-10PK', 'GP8-10PK', 'SA6 SKEWABLE ANGLE 4 X 6-3/8', 'SA4 SKEWABLE ANGLE 4-3/8 X 4', '#40 2PC EXP JNT 7/8 IN X 10FT - ZINC', '#7 WEEP/SILL SCREED 5/8 IN X 10FT - ZINC', '10FT GALVANIZED 5/8IN J-TRIM', 'FASTBACK® WOOD BACKER 5-1/8 X 10-1/2', 'ProTRAK 20 LTD 3-5/8IN DW TR 1-1/4IN LEG', 'ProTRAK 20 LTD 3-5/8IN DW TR 2-1/2IN LEG']
# Top-10 Recommendations for '5/8 Fire Rated Gypsum Board X58': ['E685 SUPPORT CLIP 14 GA 4 X 1-1/2 X 5', 'E689 SUPPORT CLIP 14 GA. 4 X 1 1/2 X 9', 'E975 SUPPORT CLIP  12 GA. 4 X 1-1/2 X 5', 'E545 SUPPORT CLIP 16 GA. 4 X 1-1/2 X 5', 'S687 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 7', 'E547 SUPPORT CLIP 16 GA. 4 X 1 1/2 X 7', 'S689 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 9', 'E979 SUPPORT CLIP 12 GA. 4 X 1-1/2 X 9', 'E971 SUPPORT CLIP 12 GA. 4 X 1-1/2 X 11', 'E549 SUPPORT CLIP 16 GA. 4 X 1-1/2 X 9']
# Top-10 Recommendations for '5/8 Fire Rated XP Gypsum Board X58XP': ['CLARKDIETRICH CD15 HOLDOWN 2-5/8IN X19IN', 'CDBV 1-5/8 X 10', 'CDBV 1-5/8 X 8', 'MBT 5/8 IN X 8FT BULL NOSE', 'EASYCLIP G686 PUNCH GUSSET PLATE 6 X 8.5', 'CLARKDIETRICH CD8 HOLDOWN 2-5/8IN X 11IN', 'MBT 5/8 IN X 10FT BULL NOSE', 'CDBV 1-5/8 X 6', 'CDBV 1-5/8 X 12', 'EASYCLIP G436 PUNCH GUSSET PLATE 6 X 8.5']
# Top-10 Recommendations for 'Acoustical Sealant ACTSEAL290Z': ['SSR210', 'HHDTPQ410', 'SSR310', 'SSR410', 'SSL210', 'SSL310', 'HHDTP410', 'HTF210', 'H210', 'SSL410']
# Top-10 Recommendations for 'Sound Batt Insulation SB1116': ['SB', 'SB-100', 'SB-100S', 'SB100 BLACK - 10FT', 'SB-50', 'SB-50S', 'SB75 - 8FT', 'SB100 -12FT', 'SB175 - 5FT', 'SB-12']
# Top-10 Recommendations for 'Sound Batt Insulation SB1916': ['SB', 'SB-100', 'SB-100S', 'SB100 BLACK - 10FT', 'SB-50', 'SB-50S', 'SB175 - 5FT', 'SB75 - 8FT', 'SB100 -12FT', 'SB-12']
# Top-10 Recommendations for 'Clip Angle CL2320': ['CHS-CLP CHASSIS CLIP', 'EASYCLIP H436 UNIVERSAL HEADER HANGER CL', 'EASYCLIP H686 UNIVERSAL HEADER HANGER CL', 'EASYCLIP H546 UNIVERSAL HEADER HANGER CL', 'ST/AD8', 'ST/AD10', 'ST/AD15', 'STRUCTALATH TWIN TRAC SS304', 'STRUCTA-V TRUSS WALL/CEILING PANELS', 'NON SLIP STIX COMPONENT C']
# Top-10 Recommendations for '6 20ga Flat Stock FS620': ['FSB125-3IN 20G FLATSTRAPBACKER 1.25 TAPE', '1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', '3.5IN x 5.5IN 25G G40 33KSI DANBACK® PL', '3.5IN x 3.5IN 25G G40 33KSI DANBACK® PL', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', '10FT GALVANIZED 2 X 2 UTILITY ANGLE 25GA', '6 X 10 STEEL TRACK 20G', '3-5/8 X 14 STEEL STUD 20G', '6 X 10 STEEL STUD 20G', 'ProTRAK 20 LTD 3-5/8IN DW TRACK 3IN LEG']
# Top-10 Recommendations for 'Spazzer Bar bridging SPAZZER': ['SPAZZER® BAR GUARD', 'SPAZZER® BAR FLY CLIP', 'SPAZZER® GROMMET', 'FASTBACK® WOOD BACKER -24 IN O.C SPACING', 'FASTBACK® WOOD BACKER -24 IN O.C SPACING', 'FASTBACK® WOOD BACKER -12 IN O.C SPACING', 'FASTBACK® WOOD BACKER -12 IN O.C SPACING', 'FASTBACK® WOOD BACKER -16 IN O.C SPACING', 'FASTBACK® WOOD BACKER -16 IN O.C SPACING', 'BK-BRC-BRKT-STRT']
# Top-10 Recommendations for '7/8 20ga Furring Channel FC7820': ['BLAZEFRAME FC 6-3/4IN 20G', 'BLAZEFRAME FC 6-1/4IN 20G', 'BLAZEFRAME FC 7-1/4IN 18G', 'BLAZEFRAME FC 6-1/4IN 18G', 'BLAZEFRAME FC 4-1/4IN 18G', 'BLAZEFRAME FC 7IN 20G', '10FT GALVANIZED 7/8IN FURRING CHANNEL', '12FT GALVANIZED 7/8IN FURRING CHANNEL', '10FT VINYL 5/8IN J-TRIM', 'TRADEREADY TDJ24 1 3/4 FL 50K 7-1/4 16g']
# Top-10 Recommendations for '2-1/2 x 20ga Int Stud S21220-33M': ['S681 SUPPORT CLIP 14G 1-1/2 X 1-1/2 X 11', 'S541 SUPPORT CLIP 16G 1-1/2 X 1-1/2 X 11', 'S545 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 5', 'S547 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 7', 'S687 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 7', 'S689 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 9', 'S683 SUPPORT CLIP 14GA 1-1/2 X 1-1/2 X 3', 'S971 SUPPORT CLIP 12G 1-1/2 X 1-1/2 x 11', 'S543 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 3', 'S979 SUPPORT CLIP 12GA 1-1/2 X 1-1/2 X 9']
# Top-10 Recommendations for '3-5/8 x 20ga Int Stud S35820-33M': ['STRUCTURAL BLOCKING - 10 X 15-3/4 16G', 'STRUCTURAL BLOCKING - 8 X 15-3/4 16G', '362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', '362BHC8-68 - 3-5/8 X 1-1/2 X 8 - 14G']
# Top-10 Recommendations for '6 x 20ga Int Stud S620-33M': ['BARRIER MESH BM75-16GA 5 X 10', 'BARRIER MESH BM75-13GA 5 X 10', 'BARRIER MESH BM15-16GA 4 X 10', 'BARRIER MESH BM50-13GA 5 X 10', 'BARRIER MESH BM50-13GA 4 X 10', 'BARRIER MESH BM75-9GA 42.25IN X 96IN', 'DZF 2 X 2 X 2 -20G 33MIL', 'BARRIER MESH BM75-13GA 4 X 12', 'BARRIER MESH BM50-13GA 5 X 8', 'BARRIER MESH BM75-16GA 4 X 13']
# Top-10 Recommendations for '2-1/2 x 20ga Int Track T21220-33M': ['S687 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 7', 'S681 SUPPORT CLIP 14G 1-1/2 X 1-1/2 X 11', 'S689 SUPPORT CLIP 14 G 1-1/2 X 1-1/2 X 9', 'S683 SUPPORT CLIP 14GA 1-1/2 X 1-1/2 X 3', 'S547 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 7', 'S541 SUPPORT CLIP 16G 1-1/2 X 1-1/2 X 11', 'S545 SUPPORT CLIP 16GA 1-1/2 X 1-1/2 X 5', 'S971 SUPPORT CLIP 12G 1-1/2 X 1-1/2 x 11', 'S979 SUPPORT CLIP 12GA 1-1/2 X 1-1/2 X 9', 'U683 1-1/2 X 1-1/2 X 3-3/8 (14G) PUNCHED']
# Top-10 Recommendations for '2-1/2 20ga Slotted Deflection Track T21220SLOT-33': ['ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/2LEG', 'ProTRAK 22MIL-33EQ 1-5/8 DW TRK 1-1/2LEG', 'ProTRAK 22MIL-33EQ 3-1/2 DW TRK 1-1/2LEG', 'ProTRAK 20 3-5/8IN DW TRACK 1-1/2IN LEG', 'ProTRAK 22MIL-33EQ 2-1/2 DW TRK 1-1/4LEG', 'ProTRAK 25 1-5/8IN DW TRACK 2-1/2IN LEG', 'ProTRAK 22MIL-33EQ 2-1/2 DW TRK 1-1/2LEG', '2-1/2IN DEFLECTION TRACK 16G', 'ProTRAK 25 3-5/8IN DW TRACK 1-1/2IN LEG', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/4LEG']
# Top-10 Recommendations for '3-5/8 x 20ga Int Track T35820-33M': ['362BHC10-54 - 3-5/8 X 1-1/2 X 10 - 16G', '362BHC10-43 - 3-5/8 X 1-1/2 X 10 - 18G', 'STRUCTURAL BLOCKING - 10 X 15-3/4 16G', '362BHC8-43 - 3-5/8 X 1-1/2 X 8 - 18G', '362BHC8-54 - 3-5/8 X 1-1/2 X 8 - 16G', '362BHC10-68 - 3-5/8 X 1-1/2 X 10 - 14G', '362BHC6-54 - 3-5/8 X 1-1/2 X 6 - 16G', '362BHC6-43 - 3-5/8 X 1-1/2 X 6 - 18G', 'STRUCTURAL BLOCKING - 8 X 15-3/4 16G', '362BHC8-68 - 3-5/8 X 1-1/2 X 8 - 14G']
# Top-10 Recommendations for '3-5/8 20ga Int Slotted Deflection Track T35820SLOT-33': ['3-5/8IN DEFLECTION TRACK 16G', '1-5/8IN DEFLECTION TRACK 16G', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/4LEG', '3-5/8IN DEFLECTION TRACK 18G', 'ProSTUD 22MIL-33EQ 3-5/8 DW STUD 1-7/16', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRK 1-1/2LEG', '1-5/8IN DEFLECTION TRACK 18G', 'ProSTUD 22MIL-33EQ 1-5/8 DW STUD 1-7/16', 'ProSTUD 22MIL-33EQ 5-1/2 DW STUD 1-7/16', '3-5/8IN DEFLECTION TRACK']
# Top-10 Recommendations for '6 x 20ga Int Track T620-33M': ['DZF 2 X 2 X 2 -20G 33MIL', 'BARRIER MESH BM75-16GA 5 X 10', 'BARRIER MESH BM75-13GA 5 X 10', 'BARRIER MESH BM50-13GA 5 X 10', 'BARRIER MESH BM15-16GA 4 X 10', 'DZF 1.25 x 3 x 1.25 -16G', 'BARRIER MESH BM50-13GA 4 X 10', 'BARRIER MESH BM75-9GA 42.25IN X 96IN', 'DZF 1.25 X 2 X 1.25-20G', 'BARRIER MESH BM75-13GA 4 X 12']
# Top-10 Recommendations for '6 20ga Slotted Deflection Track T620SLOT-33': ['66100 T-12', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 3 LEG', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 2 LEG', 'ProTRAK 22MIL-33EQ 3-5/8 DW TRACK 1 LEG', 'ProTRAK 22MIL-33EQ 1-5/8 DW TRACK 2 LEG', 'ProSTUD 22MIL-33EQ 6 DW STUD 1-7/16', 'ProTRAK 22MIL-33EQ 1-5/8 DW TRACK 1 LEG', 'ProSTUD 22MIL-33EQ 4 DW STUD 1-7/16', 'TS-358 3IN VINYL LINER - 10FT', 'ProTRAK 22MIL-33EQ 6 DW TRACK 2-1/2 LEG']
# Top-10 Recommendations for '5/8 Cement Board Sheathing CBSHEATHS58': ['STR TRACK 3-5/8IN 18G 3-5/8IN LEGS', 'DRYWALL TRACK 3-5/8IN 20G 3-5/8IN LEGS', 'STR TRACK 3-5/8IN 20G 1-5/8IN LEGS', 'STR TRACK 3-5/8IN 16G 1-5/8IN LEGS', 'STR TRACK 3-5/8IN 18G 1-5/8IN LEGS', 'ProSTUD20 3-5/8IN DRYWALL STUD 1-7/16FL', 'STRUCTURAL STUD 3-5/8IN 10G 1-5/8IN FL', 'STRUCTURAL STUD 3-5/8IN 12G 1-5/8IN FL', 'ULTRATRAK 3-5/8IN 16G', 'HEAVY DUTY STUD 3-5/8IN 12G']
# Top-10 Recommendations for '1/2 Dens-Deck Sheathing GPDD12': ['#66 SF CASING W/ WEEP 1-1/2 IN X 10FT', 'GOLDLINE PLATINUM P1-UB 1-1/4 X 1-1/4 NA', '#66 SF CASING W/WEEP 1-1/4FT X 10FT', '1-3/8 J-TRIM N/W 3-1/2 IN FLG', 'VFL 2-1/2 X 2-1/2 - 10 FT', 'VFLC 3-1/2 X 3-1/2 - 10 FT', 'CLARKDIETRICH CD10 HOLDOWN 2-5/8X13-1/2', '1-1/2 J-TRIM N/W 1-7/8 FLG', 'BLAZEFRAME DL-W-1 2-1/2IN 20G', 'VFLE 2-1/2 X 2-1/2 - 10 FT']
# Top-10 Recommendations for '5/8 Dens-Glass Gold Sheathing GPDGG58': ['GP5-10PK', 'GP8-10PK', '#7 WEEP/SILL SCREED 5/8 IN X 10FT - ZINC', '#7 WEEP/SILL SCREED 3/4 IN X 10FT - ZINC', '#7 WEEP/SILL SCREED 7/8 IN X 10FT - ZINC', 'CDMB 1-5/8 X 8', 'CDMB 1-5/8 X 10', 'BLAZEFRAME DL-W-2 3-5/8IN 20G', 'CDMB 1-5/8 X 6', 'SA4 SKEWABLE ANGLE 4-3/8 X 4']
# Top-10 Recommendations for 'Durabond Easy Sand Setting Compound DURABONDES': ['LEPB4', 'LEHJG', 'FLEX-LATH', 'VINYL DRYWALL CORNER BEAD 120 DEG 8FT', 'FLAT DM APB UTILITY LATH 97 IN', 'FLAT UTILITY METAL LATH 97 IN', 'STRUCTA-MEGA LATH', 'WIRE STUCCO BULLNOSE ARCH CORNER 90 DEGR', 'MEGA-LATH STAINLESS STEEL 304 ALLOY', 'SF DIMPLE APB UTILITY LATH 97 IN']
# Top-10 Recommendations for 'Tape 250' Roll TAPE-250': ['WS58-250U-200 - 10FT', 'WS58-250U-200 TAN - 10FT', 'CS75-150-150 A', '1575R-150 X 1575R-150 CROSSES', '1558R-400V-10', 'WS78-350U-10 BLACK', 'CS75-150-150 - 10FT', '1558R-300V-10 GRAY', 'CS58-150-150 - 10FT', 'WS78-250U-10 GRAY']
# Top-10 Recommendations for 'Taping Compound TFCMPND': ['TPA4G', 'T12', 'TGHW4', 'TGH3', 'TPA6G', 'TGHW3', 'TGH2', 'T1212', '1575EF T', 'TGHH4']
# Top-10 Recommendations for '6 Mill Poly POLY6M': ['DRYWALL STUD 3-5/8IN 30M SPRINKLER NOTCH', 'ProSTUD 25 4IN DRYWALL STUD', 'ProSTUD 25 6IN DRYWALL STUD', '4 TRAKLOC ELEVATOR STUD 33M 12FT 2IN', '6 TRAKLOC ELEVATOR STUD 33M 12FT 2IN', '4 TRAKLOC ELEVATOR STUD 33M 18FT 3IN', '6 TRAKLOC ELEVATOR STUD 33M 18FT 3IN', '6 TRAKLOC ELEVATOR STUD 33M 16FT 2IN', '4 TRAKLOC ELEVATOR STUD 33M 16FT 2IN', 'ProSTUD 20 LTD 4IN DRYWALL STUD']
# Top-10 Recommendations for 'Corner Bead CB10': ['10FT PAPER FACED OUTSIDE SUPERWIDE CB', '8FT PAPER FACED OUTSIDE SUPERWIDE CB', 'CB158E - 10 FT', 'CB138E - 10 FT', 'CB125 - 10 FT', 'CB158E - 8 FT', 'CB138E - 8 FT', '1005989927 - 9FT VINYL BULLNOSE CB', 'CB125 - 12 FT', 'CB125A - 10 FT']
# Top-10 Recommendations for 'Control Joint CJ093': ['CJ100', 'CJ58', 'CJ50', 'CJ38', 'CJ75', 'CJ78', 'CJV16-C', 'R210', 'R410', 'CX100']
# Top-10 Recommendations for '1/2 tearaway plastic L bead TEARAWAY12': ['10FT VINYL 1/2IN L TRIM W/TEAR STRIP', '10FT GALVANIZED 1/2IN L-TRIM', '1/2 IN VINYL L TRIM', '10FT VINYL 1/2IN L-TRIM', '1/2 IN VINYL MUDABLE J BEAD 8FT', '10FT GALVANIZED 1/2IN J-TRIM', '2IN JWLB W/WEEP, 1-3/8IN', '1/2IN #200B L-TRIM', '3/4 IN J-TRIM N/W 3-1/2 FLG', 'GOLDLINE PLATINUM P1-O 1/2 X 3/4 OFF ANG']
# Top-10 Recommendations for '2x4 Fire Treated 204FT': ['15187X - 10FT', '1.5 COMPOSITE DECK 20G 36INX24FT', '1.5 COMPOSITE DECK 18G 36INX24FT', 'BLAZEFRAME ODSLX-2 4IN 20G', 'BLAZEFRAME ODSLX-2 4IN 14G', 'BLAZEFRAME ODSLX-2 4IN 16G', 'BLAZEFRAME ODLX-2 4IN 20G', 'BLAZEFRAME ODSLX-2 6IN 20G', 'BLAZEFRAME ODLX-2 4IN 14G', 'BLAZEFRAME ODSLX-2 4IN 18G']
# Top-10 Recommendations for '2x6 Fire Treated 206FT': ['15187X - 10FT', 'BLAZEFRAME ODSLX-2 4IN 20G', 'BLAZEFRAME ODSLX-2 4IN 14G', 'BLAZEFRAME ODSLX-2 4IN 16G', 'BLAZEFRAME ODSLX-2 4IN 18G', 'BLAZEFRAME ODSLX-2 6IN 20G', 'BLAZEFRAME ODSLX-2 6IN 14G', 'BLAZEFRAME ODSLX-2 6IN 16G', '1.5 COMPOSITE DECK 20G 36INX24FT', '1.5 COMPOSITE DECK 18G 36INX24FT']
# Top-10 Recommendations for '2x8 Fire Treated 208FT': ['15187X - 10FT', 'BLAZEFRAME ODSLX-2 4IN 20G', 'BLAZEFRAME ODSLX-2 4IN 14G', '1558X-10 GRAY', '1518X-10', 'BLAZEFRAME ODSLX-2 4IN 16G', '1.5 COMPOSITE DECK 20G 36INX24FT', '1.5 COMPOSITE DECK 18G 36INX24FT', 'BLAZEFRAME ODSLX-2 6IN 20G', 'BLAZEFRAME ODSLX-2 4IN 18G']
# Top-10 Recommendations for '1/2 CDX F/R Plywood PLY12FT': ['CD1-WU OR P1-W (1/2 X 3/4 SQ OUTSIDE)', 'VLFB - F BEAD 1/2IN', '#66X EXP FLG CASING W/WEEP 1/2 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT', '1/2 IN #7 SILL SCREED N/H', '#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '3/4 IN J-TRIM N/W 3-1/2 FLG', '#66X EXP FLG CASING W/WEEP 3/8 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1 IN X 10FT', '#66X EXP FLG CASING W/WEEP 5/8 IN X 10FT']
# Top-10 Recommendations for '3/4 CDX Fire-treated Plywood PLY34FT': ['CD1-SWE or P1-SU(1-1/8IN SQUARE OUTSIDE)', 'CLARKDIETRICH CD10 HOLDOWN 2-5/8X13-1/2', 'CD1-WU OR P1-W (1/2 X 3/4 SQ OUTSIDE)', '#66X EXP FLG CASING WEEP 3/4 X10FT-ZINC', '#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT', 'CD1-WE or P1-U (3/4IN SQUARE OUTSIDE)', '#66X EXP FLG CASING W/WEEP 1/2 IN X 10FT', '#66X EXP FLG CASING WEEP 1/4 X10FT-ZINC', '#66X EXP FL CASING WEEP 1-1/2 X10FT-ZINC']
# Top-10 Recommendations for '3/4 T&G Underlayment PLY34UNDTG': ['#7 SILL N/H 3-1/2 FLG (26G)', '#36 SILL N/H 3-1/2 FLG (26G)', 'GOLDLINE PLATINUM P1-O 1/2 X 3/4 OFF ANG', '3/4 IN J-TRIM N/W 3-1/2 FLG', '1/2 IN #7 SILL SCREED N/H', 'DANBACK® WOOD BACKING F/T  16 IN OC', '#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/2 IN X 10FT', '10FT VINYL 1/2IN L TRIM W/TEAR STRIP']
# Top-10 Recommendations for '5/8 fire treated plywood PLY58FT': ['SA6 SKEWABLE ANGLE 4 X 6-3/8', 'SA4 SKEWABLE ANGLE 4-3/8 X 4', '#7 SILL N/H 3-1/2 FLG (26G)', '#66X EXP FLG CASING W/WEEP 5/8 IN X 10FT', '#66X EXP FLG CASING W/WEEP 7/8 IN X 10FT', '#36 SILL N/H 3-1/2 FLG (26G)', '#66X EXP FLG CASING W/WEEP 3/8 IN X 10FT', '#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '#7 7/8 SILL 3-1/2 FLG (26G) CODE', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT']
# Top-10 Recommendations for '2x4 Pressure Treated Roof Blocking 204PTRF': ['1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', '1.5 COMPOSITE DECK 20G 36INX24FT', '1.5 COMPOSITE DECK 18G 36INX24FT', '15100X-10 GRAY', '15187X - 10FT', '15100X-10 BROWN', 'BLAZEFRAME ODSLX-2 4IN 20G', '1575X-10 GRAY', '1558X-10 GRAY']
# Top-10 Recommendations for '2x6 Pressure Treated Roof Blocking 206PTRF': ['BLAZEFRAME ODSLX-2 4IN 20G', 'BLAZEFRAME ODSLX-2 4IN 14G', '1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', 'BLAZEFRAME ODSLX-2 4IN 18G', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', 'BLAZEFRAME ODSLX-2 4IN 16G', 'BLAZEFRAME ODSLX-2 6IN 20G', 'BLAZEFRAME ODSLX-2 6IN 14G', '15187X - 10FT', '15100X-10 GRAY']
# Top-10 Recommendations for '2x8 Pressure Treated Roof Blocking 208PTRF': ['15187X - 10FT', '1558X-10 GRAY', '1578X-10 GRAY', '1518X-10', '1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', 'BLAZEFRAME ODSLX-2 4IN 20G', '15100X-10 GRAY', '1575X-10 GRAY', 'BLAZEFRAME ODSLX-2 4IN 14G']
# Top-10 Recommendations for '2x4 Pressure Treated Window Blkg 204PTW': ['BARRIER MESH BM75-13 FLAT 4X10', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', '1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', '2 1/2 JL CORNER (20G)', '18MIL 2-1/2IN DW TRK 2IN LEG', '18MIL 3-1/2IN DW TRK 2IN LEG', '2 1/2 JL CORNER (25G)', 'BLAZEFRAME ODLX-2 4IN 14G', 'CXJ-78X-10 GRAY', '18MIL 4IN DW TRK 1-1/2IN LEG']
# Top-10 Recommendations for '2x6 Pressure Treated Window Bikg 206PTW': ['#66X EXP FLG CASING 1/2 IN X 10FT', '#66X EXP FLG CASING 3/4 IN X 10FT', '#66X EXP FLG CASING 1/4 IN X 10FT', '#66X EXP FLG CASING 1 IN X 10FT', '#66X EXP CASING 1/2 IN X 12FT', '#66X EXP FLG CASING 3/8 IN X 10FT', '#66X EXP CASING 3/4 IN X 8FT', '18MIL 4IN DW TRK 2IN LEG', '#66X EXP FLG CASING 5/8 IN X 10FT', '18MIL 6IN DW TRK 2IN LEG']
# Top-10 Recommendations for '2x8 Pressure Treated Window Blkg 208PTW': ['BARRIER MESH BM75-13 FLAT 4X10', '1.5IN TYPE B ROOF DECK 22G 36INX24FT4IN', '1.5IN TYPE B ROOF DECK 20G 36INX24FT4IN', '18MIL 2-1/2IN DW TRK 2IN LEG', '18MIL 3-1/2IN DW TRK 2IN LEG', '2 1/2 JL CORNER (20G)', 'CXJ-78X-10 GRAY', '2 1/2 JL CORNER (25G)', '18MIL 4IN DW TRK 1-1/2IN LEG', '18MIL 4IN DW TRK 2IN LEG']
# Top-10 Recommendations for '1/2 CDX Pressure treated Plywood PLY12PTW': ['#66X EXP FLG CASING W/WEEP 1/2 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT', 'CD1-WU OR P1-W (1/2 X 3/4 SQ OUTSIDE)', '#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 3/8 IN X 10FT', 'CD1-SWE or P1-SU(1-1/8IN SQUARE OUTSIDE)', '#66X EXP FLG CASING WEEP 1/2 X10FT-ZINC', '#66X EXP FLG CASING W/WEEP 1 IN X 10FT', '#66X EXP FLG CASING WEEP 1/4 X10FT-ZINC', '#66X EXP FLG CASING W/WEEP 5/8 IN X 10FT']
# Top-10 Recommendations for '3/4 CDX Pressure treated Plywood PLY34PTW': ['#66X EXP FLG CASING W/WEEP 3/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1/2 IN X 10FT', '#66X EXP FLG CASING W/WEEP 3/8 IN X 10FT', '#66X EXP FLG CASING W/WEEP 5/8 IN X 10FT', '#66X EXP FLG CASING WEEP 3/4 X10FT-ZINC', '#66X EXP FLG CASING W/WEEP 7/8 IN X 10FT', '#66X EXP FLG CASING WEEP 1/4 X10FT-ZINC', '#66X EXP FLG CASING 3/4 IN X 10FT', '#66X EXP FLG CASING W/WEEP 1 IN X 10FT']
